# %% [markdown]
# <a href="https://colab.research.google.com/github/fran-castillo/Colab-Notebooks/blob/main/PGN_to_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pgn2data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 KB 7.2 MB/s eta 0:00:00
# ...

# %%
from converter.pgn_data import PGNData

pgn_data = PGNData('lichess.pgn')
result = pgn_data.export()

# %%
import pandas as pd

# %%
data1=pd.read_csv('lichess_game_info.csv', encoding='utf-8')
data2=pd.read_csv('lichess_moves.csv')
data1
# Out:
#                                    game_id  game_order              event  \
# 0     7ea286fd-f5b3-4e46-8b3f-4612cfc59089           1   Rated Rapid game
# 1     a3348fbe-c819-4970-ac17-780dacbc754f           2  Casual Rapid game
# 2     a5d6dc0d-a334-4898-a87f-1727247b1dc8           3   Rated Rapid game
# 3     8aa724f4-fe37-4134-97b2-328da7c94474           4   Rated Rapid game
# 4     2d882e75-d43f-43bc-a595-5311f42fef87           5   Rated Rapid game
# ...                                    ...         ...                ...
# 2506  e143237f-aa7b-4ef4-aeaa-9c94abacea1d        2507   Rated Blitz game
# 2507  14b3a6ea-ddbf-4dd9-81d1-5a8edffa3194        2508   Rated Blitz game
# 2508  20102ee7-c060-4b7e-8a10-1f73f38e879c        2509   Rated Blitz game
# 2509  d9328c5a-635e-4e63-8d91-c448b2f983b0        2510   Rated Blitz game
# 2510  45f70671-ab01-487e-a9f6-090ff2c09f46        2511   Rated Blitz game
#
#                               site date_played round           white  \
# ...
